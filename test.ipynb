# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Meiryo' in f.name])
# Out:
# ['Meiryo', 'Meiryo']

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0
